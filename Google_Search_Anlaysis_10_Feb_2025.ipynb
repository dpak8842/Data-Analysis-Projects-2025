# %% [markdown]
# <a href="https://colab.research.google.com/github/dpak8842/Data-Analysis-Projects-2025/blob/main/Google_Search_Anlaysis_10_Feb_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Diversity Hiring"])

# %%
data = trends.interest_by_region()

# %%
data = data.sort_values(by="Diversity Hiring", ascending=False)

# %%
data
# Out:
#                Diversity Hiring
# geoName
# United States               100
# Singapore                   100
# Canada                       75
# Kenya                        75
# Ireland                      50
# ...                         ...
# Guadeloupe                    0
# Guam                          0
# Guatemala                     0
# Guernsey                      0
# French Guiana                 0
#
# [250 rows x 1 columns]

# %%
data = data.head(10)

# %%
data
# Out:
#                Diversity Hiring
# geoName
# United States               100
# Singapore                   100
# Canada                       75
# Kenya                        75
# Ireland                      50
# South Korea                  50
# Philippines                  50
# India                        25
# Australia                    25
# Hong Kong                    25

# %%
print(data)
# Out:
#                Diversity Hiring
# geoName
# United States               100
# Singapore                   100
# Canada                       75
# Kenya                        75
# Ireland                      50
# South Korea                  50
# Philippines                  50
# India                        25
# Australia                    25
# Hong Kong                    25

# %%
data.reset_index().plot(x="geoName",
                        y="Diversity Hiring",
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Diversity Hiring'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Diversity Hiring'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Diversity Hiring',
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %% [markdown]
# The graph titled "Total Google Searches for Diversity Hiring" illustrates the trends in search interest related to the topic of diversity hiring over a period from 2021 to early 2025. Here’s a summary of the key features:
#
# Overall Trend: The graph shows fluctuations in search interest over the years, with periods of both increases and decreases in total search counts.
#
# Initial Spike: At the beginning of 2021, there’s a noticeable spike in searches, indicating a significant rise in interest during that time.
#
# Gradual Fluctuations: Following the spike, the graph exhibits a generally decreasing trend with minor fluctuations, suggesting that interest in diversity hiring varied but stayed relatively low into 2022.
#
# Mid-2024 Activity: A slight resurgence in searches occurs around mid-2024, indicating renewed interest in diversity hiring initiatives.
#
# Recent Surge: The most dramatic increase is observed at the end of the recorded period in 2025, where search counts soar to a peak of 100, suggesting a significant uptick in interest, possibly tied to external events or changes in the workplace environment regarding diversity hiring.
#
# Overall, the graph captures the evolving interest in diversity hiring over time, highlighting moments of both heightened and subdued focus on the topic.
